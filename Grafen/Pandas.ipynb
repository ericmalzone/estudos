# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("dataset/test_titanic.csv")

# %%
df.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
df.describe()
# Out:
#        PassengerId      Pclass         Age       SibSp       Parch        Fare
# count   418.000000  418.000000  332.000000  418.000000  418.000000  417.000000
# mean   1100.500000    2.265550   30.272590    0.447368    0.392344   35.627188
# std     120.810458    0.841838   14.181209    0.896760    0.981429   55.907576
# min     892.000000    1.000000    0.170000    0.000000    0.000000    0.000000
# 25%     996.250000    1.000000   21.000000    0.000000    0.000000    7.895800
# 50%    1100.500000    3.000000   27.000000    0.000000    0.000000   14.454200
# 75%    1204.750000    3.000000   39.000000    1.000000    0.000000   31.500000
# max    1309.000000    3.000000   76.000000    8.000000    9.000000  512.329200

# %%
df.shape
# Out:
# (418, 11)

# %% [markdown]
# SIZE multiplica linhas x colunas

# %%
df.size
# Out:
# 4598

# %%
len(df) #linhas
# Out:
# 418

# %%
len(df.columns) #colunas
# Out:
# 11

# %%
df.columns
# Out:
# Index(['PassengerId', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch',
#        'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df["Name"] #Assim o pandas coloca "..." no meio porque antes ele coloca um pouco de linhas do inicio e depois dos "..." linhas do fim
# Out:
# 0                                       Kelly, Mr. James
# 1                       Wilkes, Mrs. James (Ellen Needs)
# 2                              Myles, Mr. Thomas Francis
# 3                                       Wirz, Mr. Albert
# 4           Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# 5                             Svensson, Mr. Johan Cervin
# 6                                   Connolly, Miss. Kate
# 7                           Caldwell, Mr. Albert Francis
# 8              Abrahim, Mrs. Joseph (Sophie Halaut Easu)
# 9                                Davies, Mr. John Samuel
# 10                                      Ilieff, Mr. Ylio
# 11                            Jones, Mr. Charles Cresson
# 12         Snyder, Mrs. John Pillsbury (Nelle Stevenson)
# 13                                  Howard, Mr. Benjamin
# 14     Chaffee, Mrs. Herbert Fuller (Carrie Constance...
# 15         del Carlo, Mrs. Sebastiano (Argenia Genovesi)
# ...

# %%
df["Name"][5] # Só trouxe a 5ª linha
# Out:
# 'Svensson, Mr. Johan Cervin'

# %%
df["Name"][:5] #Assim só as primeiras 5 linhas, o 0 não precisa colocar antes dos ":"
# Out:
# 0                                Kelly, Mr. James
# 1                Wilkes, Mrs. James (Ellen Needs)
# 2                       Myles, Mr. Thomas Francis
# 3                                Wirz, Mr. Albert
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# Name: Name, dtype: object

# %%
df[["Name", "Sex"]]
# Out:
#                                                   Name     Sex
# 0                                     Kelly, Mr. James    male
# 1                     Wilkes, Mrs. James (Ellen Needs)  female
# 2                            Myles, Mr. Thomas Francis    male
# 3                                     Wirz, Mr. Albert    male
# 4         Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
# 5                           Svensson, Mr. Johan Cervin    male
# 6                                 Connolly, Miss. Kate  female
# 7                         Caldwell, Mr. Albert Francis    male
# 8            Abrahim, Mrs. Joseph (Sophie Halaut Easu)  female
# 9                              Davies, Mr. John Samuel    male
# 10                                    Ilieff, Mr. Ylio    male
# 11                          Jones, Mr. Charles Cresson    male
# 12       Snyder, Mrs. John Pillsbury (Nelle Stevenson)  female
# 13                                Howard, Mr. Benjamin    male
# ...

# %%
df[df["Sex"] == "female"][:5] #Uma forma de filtrar no DataFrame, e coloquei pra trazer só as 5 primeiras linhas
# Out:
#     PassengerId  Pclass                                           Name  \
# 1           893       3               Wilkes, Mrs. James (Ellen Needs)
# 4           896       3   Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# 6           898       3                           Connolly, Miss. Kate
# 8           900       3      Abrahim, Mrs. Joseph (Sophie Halaut Easu)
# 12          904       1  Snyder, Mrs. John Pillsbury (Nelle Stevenson)
#
#        Sex   Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 1   female  47.0      1      0   363272   7.0000   NaN        S
# 4   female  22.0      1      1  3101298  12.2875   NaN        S
# 6   female  30.0      0      0   330972   7.6292   NaN        Q
# 8   female  18.0      0      0     2657   7.2292   NaN        C
# 12  female  23.0      1      0    21228  82.2667   B45        S

# %%
df[(df["Pclass"] == 1) | (df["Pclass"] == 2)]
# Out:
#      PassengerId  Pclass                                               Name  \
# 2            894       2                          Myles, Mr. Thomas Francis
# 7            899       2                       Caldwell, Mr. Albert Francis
# 11           903       1                         Jones, Mr. Charles Cresson
# 12           904       1      Snyder, Mrs. John Pillsbury (Nelle Stevenson)
# 13           905       2                               Howard, Mr. Benjamin
# 14           906       1  Chaffee, Mrs. Herbert Fuller (Carrie Constance...
# 15           907       2      del Carlo, Mrs. Sebastiano (Argenia Genovesi)
# 16           908       2                                  Keane, Mr. Daniel
# 20           912       1                             Rothschild, Mr. Martin
# 22           914       1               Flegenheim, Mrs. Alfred (Antoinette)
# 23           915       1                    Williams, Mr. Richard Norris II
# ...

# %%
df[(df["Pclass"] == 1) & (df["Sex"] == "female")]
# Out:
#      PassengerId  Pclass                                               Name  \
# 12           904       1      Snyder, Mrs. John Pillsbury (Nelle Stevenson)
# 14           906       1  Chaffee, Mrs. Herbert Fuller (Carrie Constance...
# 22           914       1               Flegenheim, Mrs. Alfred (Antoinette)
# 24           916       1    Ryerson, Mrs. Arthur Larned (Emily Maria Borie)
# 26           918       1                       Ostby, Miss. Helene Ragnhild
# 44           936       1   Kimball, Mrs. Edwin Nelson Jr (Gertrude Parsons)
# 48           940       1    Bucknell, Mrs. William Robert (Emma Eliza Ward)
# 53           945       1                         Fortune, Miss. Ethel Flora
# 59           951       1                        Chaudanson, Miss. Victorine
# 69           961       1                Fortune, Mrs. Mark (Mary McDougald)
# 74           966       1                               Geiger, Miss. Amalie
# ...

# %% [markdown]
# Fazer count da coluna

# %%
df1 = df["Age"].value_counts()

# %%
df1
# Out:
# 24.00    17
# 21.00    17
# 22.00    16
# 30.00    15
# 18.00    13
# 27.00    12
# 26.00    12
# 25.00    11
# 23.00    11
# 29.00    10
# 36.00     9
# 45.00     9
# 20.00     8
# 17.00     7
# 28.00     7
# 32.00     6
# 31.00     6
# 55.00     6
# 33.00     6
# 39.00     6
# 35.00     5
# 41.00     5
# 47.00     5
# 40.00     5
# 50.00     5
# 42.00     5
# 48.00     5
# 19.00     4
# 43.00     4
# 1.00      3
#          ..
# 8.00      2
# 63.00     2
# 14.00     2
# 22.50     1
# 62.00     1
# 0.83      1
# 67.00     1
# 28.50     1
# 0.33      1
# 0.17      1
# 38.50     1
# 3.00      1
# 51.00     1
# 5.00      1
# 44.00     1
# 14.50     1
# 59.00     1
# 58.00     1
# 0.75      1
# 0.92      1
# 36.50     1
# 40.50     1
# 11.50     1
# 34.00     1
# 15.00     1
# 7.00      1
# 60.50     1
# 26.50     1
# 76.00     1
# 34.50     1
# Name: Age, Length: 79, dtype: int64

# %% [markdown]
# Plotando o count

# %%
df1.plot(kind="bar")

# %% [markdown]
# # Exercicios

# %%
df = pd.read_csv("dataset/test_titanic.csv")

# %%
man = df[df["Sex"] == "male"]

# %%
man.head()
# Out:
#    PassengerId  Pclass                          Name   Sex   Age  SibSp  \
# 0          892       3              Kelly, Mr. James  male  34.5      0
# 2          894       2     Myles, Mr. Thomas Francis  male  62.0      0
# 3          895       3              Wirz, Mr. Albert  male  27.0      0
# 5          897       3    Svensson, Mr. Johan Cervin  male  14.0      0
# 7          899       2  Caldwell, Mr. Albert Francis  male  26.0      1
#
#    Parch  Ticket     Fare Cabin Embarked
# 0      0  330911   7.8292   NaN        Q
# 2      0  240276   9.6875   NaN        Q
# 3      0  315154   8.6625   NaN        S
# 5      0    7538   9.2250   NaN        S
# 7      1  248738  29.0000   NaN        S

# %%
woman = df[df["Sex"] == "female"]

# %%
woman.head()
# Out:
#     PassengerId  Pclass                                           Name  \
# 1           893       3               Wilkes, Mrs. James (Ellen Needs)
# 4           896       3   Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# 6           898       3                           Connolly, Miss. Kate
# 8           900       3      Abrahim, Mrs. Joseph (Sophie Halaut Easu)
# 12          904       1  Snyder, Mrs. John Pillsbury (Nelle Stevenson)
#
#        Sex   Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 1   female  47.0      1      0   363272   7.0000   NaN        S
# 4   female  22.0      1      1  3101298  12.2875   NaN        S
# 6   female  30.0      0      0   330972   7.6292   NaN        Q
# 8   female  18.0      0      0     2657   7.2292   NaN        C
# 12  female  23.0      1      0    21228  82.2667   B45        S

# %%
children_m = df[(df["Age"] >= 10) & (df["Sex"] == "male")]

# %%
children_m1 = df[(df["Age"] < 10) & (df["Sex"] == "male")]

# %%
children_f = df[(df["Age"] >= 10) & (df["Sex"] == "female")]

# %%
children_f1 = df[(df["Age"] < 10) & (df["Sex"] == "female")]

# %%
g1 = children_m["Age"][:50].value_counts()

# %%
g1.plot(kind="bar")

# %%
g2 = children_m1["Age"][:50].value_counts()

# %%
g2.plot(kind="bar")

# %%
g3 = children_f["Age"][:50].value_counts()

# %%
g3.plot(kind="bar")

# %%
g4 = children_f1["Age"][:50].value_counts()

# %%
g4.plot(kind="bar",stacked=True)

# %%
vr = df[(df["Age"] > 50) & (df["Pclass"] == 1)]

# %%
g5 = vr["Age"].value_counts()

# %%
g5.plot(kind="box")

# %%
g6 = man["Age"][:50].value_counts() #obs a variavel 'man' ta mais pra cima onde filtrei no DataFrame

# %%
g6.plot(kind="pie")

# %%
g7 = woman["Age"][:50].value_counts() #obs a variavel 'woman' ta mais pra cima onde filtrei no DataFrame

# %%
g7.plot(kind="kde")
